# %% [markdown]
# #### **Exercise 1:**
# Give students in the `example.csv` file a bonus of 5 for all the courses. Find a way to replace all the values that are now greater than 30 by 30. Save the new data to a file. Make a plot with histograms for every course in the example file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/example.csv", index_col=0)

df_new = df + 5
df_new[df_new > 30] = 30

df_new.to_csv("example_new.csv")

for col in df_new.columns:
    df[col].plot(kind="hist")
    plt.title(col)
    plt.show()

# %%
df_new
# Out:
#         course1  course2  course3  course4
# name
# Marie        29       23       30       25
# John         23       30       30       30
# Kati         26       29       30       30
# Olaf         30       30       30       30
# Mark         29       30       30       26
# Olga         28       30       30       30
# Jean         23       30       30       29
# Alex         24       25       30       30
# Pier         29       30       28       30
# Bennet       29       30       30       30
# Luis         25       25       23       23

# %% [markdown]
# #### **Exercise 2:**
#
#  - Read in the `cars.csv` file as a dataframe
#  - Remove the row with the index 3, which contains a quote in the Model column.
#  - Add a new column called Price with the following values: [8000, 6500, 7000, 6800, 7500, 7300, 7000, 9000, 6500, 7800]
#  - Find the average Length of all the vehicles.
#  - Find the median Price of all the vehicles.
#  - Create a new dataframe that only contains the rows where the Price is greater than 7000.
#  - Sort the dataframe in descending order by the Price column.

# %% [markdown]
# #### **Exercise 3:**
#  - create a random matrix with numpy
#  - save it to file
#  - read it back with numpy
#  - calculate some statistcs on it with numpy
#  - read the same file with pandas
#  - calculate the same statistics on it with pandas

# %%
# Exercise 2
df = pd.read_csv("./data/cars.csv", index_col=0)
df = df.drop("Model", axis='columns')

df["Price"] = [8000, 6500, 7000, 6800, 7500, 7300, 7000, 9000, 6500, 7800]

mean = df["Length"].mean()
print("Mean length: ", mean)

median = df["Price"].median()
print("Median price: ", median)
# Out:
# Mean length:  2.522
# Median price:  7150.0

# %%
def_new = df[df["Price"] > 7000]
def_new = def_new.sort_values(by="Price", ascending=False)

def_new
# Out:
#        Make  Length  Price
# Year
# 1996   Ford    2.37   9000
# 1997   Ford    2.34   8000
# 1997   Ford    2.34   7800
# 1998  Dodge    3.01   7500
# 1997   Ford    2.34   7300

# %%
# Exercise 3
mat = np.random.random((5, 5))
mat_np = np.savetxt("matrix.csv", mat, delimiter=",")

print(df)
# Out:
#           0         1         2         3         4
# 0  0.588508  0.146144  0.337247  0.548057  0.095349
# 1  0.653836  0.811234  0.973983  0.225368  0.875463
# 2  0.724779  0.466619  0.658541  0.270669  0.509903
# 3  0.168597  0.697151  0.561433  0.692116  0.323848
# 4  0.006591  0.012089  0.589539  0.106360  0.023971

# %%
mat_np = np.loadtxt("matrix.csv", delimiter=",")

print("mean:", mat_np.mean())
print("std :", mat_np.std())
print("min :", mat_np.min())
print("max :", mat_np.max())
# Out:
# mean: 0.39001140741550244
# std : 0.2449302191450018
# min : 0.006660724689115938
# max : 0.9852921934659559

# %%
mat_df = pd.read_csv("matrix.csv", header=None)

print("mean:", mat_df.values.mean())
print("std :", mat_df.values.std())
print("min :", mat_df.values.min())
print("max :", mat_df.values.max())
# Out:
# mean: 0.3900114074155025
# std : 0.2449302191450018
# min : 0.006660724689115938
# max : 0.9852921934659559
